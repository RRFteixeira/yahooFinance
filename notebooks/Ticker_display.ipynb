# %%
import pandas as pd

date = '2025_10_05'
category= 'semiconductors'
ticker = 'TOELY'


df = pd.read_parquet(path = f"../data/raw/{date}/{category}/{ticker}.parquet")

display(df.columns)

df.columns
type(df.columns)

df = df.reset_index()
df.head()

print(df.columns)
print(df.isnull().sum())
print(f"Row count: {len(df)}")
print(f"Duplicates: {df.duplicated().sum()}")
print(f"Time range: {df['Datetime'].min()} → {df['Datetime'].max()}")

df['hour'] = df['Datetime'].dt.hour
print(df.groupby('hour').size())


print(f"how many minutes in a day: { df[df.Datetime < '2025-09-05' ]['Datetime'].count()} ")


import pandas as pd
from pathlib import Path
import ast


print(df.columns.tolist())
display(df.head())

# Plot
df.plot(x="Datetime", y="Close", figsize=(10,5), title=f"{ticker} Closing Prices")
df.plot(x="Datetime", y=["High", "Close", "Open"], figsize=(10,5), title=f"{ticker} Closing Prices")
# Out:
# Index(['Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
# Index(['index', 'Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open',
#        'Volume'],
#       dtype='object')
# index        0
# Datetime     0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
# Row count: 294
# Duplicates: 0
# Time range: 2025-09-25 13:35:00+00:00 → 2025-10-03 19:59:00+00:00
# hour
# 13    23
# 14    33
# 15    50
# 16    32
# 17    37
# 18    51
# 19    68
# dtype: int64
# how many minutes in a day: 0
# ['index', 'Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'hour']
#    index                  Datetime  Adj Close      Close       High  \
# 0      0 2025-09-25 13:35:00+00:00  91.110001  91.110001  91.110001
# 1      1 2025-09-25 13:39:00+00:00  91.000000  91.000000  91.000000
# 2      2 2025-09-25 13:43:00+00:00  90.540001  90.540001  90.650002
# ...

# %%
# Out:
# Index(['index', 'Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open',
#        'Volume'],
#       dtype='object')
# index        0
# Datetime     0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
# Row count: 2505
# Duplicates: 0
# Time range: 2025-09-18 13:30:00+00:00 → 2025-09-26 19:59:00+00:00

# %%
# Out:
# hour
# 13    202
# 14    397
# 15    386
# 16    367
# 17    366
# 18    383
# 19    404
# dtype: int64
# how many minutes in a day: 0

# %%
# Out:
# ['index', 'Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'hour']
#    index                  Datetime   Adj Close       Close        High  \
# 0      0 2025-09-18 13:30:00+00:00  360.924988  360.924988  361.390015
# 1      1 2025-09-18 13:31:00+00:00  361.505005  361.505005  362.000000
# 2      2 2025-09-18 13:32:00+00:00  360.197601  360.197601  361.450012
# 3      3 2025-09-18 13:33:00+00:00  358.209991  358.209991  358.924988
# 4      4 2025-09-18 13:34:00+00:00  357.839996  357.839996  358.250000
#
#           Low        Open  Volume  hour
# 0  358.304993  360.674988   82140    13
# 1  360.510010  361.222198   13911    13
# 2  359.214996  361.450012   10931    13
# 3  358.209991  358.924988    3145    13
# 4  357.005615  358.250000    5439    13
# <Axes: title={'center': 'AAPL Closing Prices'}, xlabel='Datetime'>

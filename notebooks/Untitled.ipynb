# %%
import pandas as pd
import matplotlib

df = pd.read_parquet(path = "../data/AAPL_prices.parquet")

display(df.columns)

df.columns
type(df.columns)
# Out:
# Index(['Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume',
#        'ticker'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
import pandas as pd
from pathlib import Path
import ast


print(df.columns.tolist())
display(df.head())

# Plot
df.plot(x="Datetime", y="Close", figsize=(10,5), title="AAPL Closing Prices")
df.plot(x="Datetime", y=["High", "Close", "Open"], figsize=(10,5), title="AAPL Closing Prices")
# Out:
# ['Datetime', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'ticker']
#                    Datetime   Adj Close       Close        High         Low  \
# 0 2025-08-25 13:30:00+00:00  226.589996  226.589996  227.130005  226.259995
# 1 2025-08-25 13:31:00+00:00  226.490005  226.490005  226.940002  226.240005
# 2 2025-08-25 13:33:00+00:00  226.880005  226.880005  227.225006  226.850006
# 3 2025-08-25 13:34:00+00:00  226.880005  226.880005  227.180298  226.750000
# 4 2025-08-25 13:35:00+00:00  226.880005  226.880005  227.169998  226.860001
#
#          Open   Volume ticker
# 0  226.404999  1262658   AAPL
# 1  226.554993   149206   AAPL
# 2  227.225006   235811   AAPL
# 3  226.839996    96486   AAPL
# 4  226.860001   102867   AAPL
# <Axes: title={'center': 'AAPL Closing Prices'}, xlabel='Datetime'>
